# %% [markdown]
# <a href="https://colab.research.google.com/github/abhimanyubhowmik/Underwater_Depth_Estimation/blob/main/initial_scripts/Deep_Anything_Initial_Script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import AutoImageProcessor, AutoModelForDepthEstimation
import torch
import numpy as np
from PIL import Image
import os
import cv2
import random
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/MyDrive/SpermWhaleData'

video1 = os.path.join(data_path, 'GX010047.MP4')
video2 = os.path.join(data_path, 'GX010068.MP4')
video_long = os.path.join(data_path, 'GX010064.MP4')
capture1 = cv2.VideoCapture(video1)
capture2 = cv2.VideoCapture(video2)
capture3 = cv2.VideoCapture(video_long)

# %%
try:
# creating a folder named data
    if not os.path.exists('data'):
        os.makedirs('data')

# if not created then raise error
except OSError:
    print ('Error: Creating directory of data')

# %%
def videoFrameExtract(video,path_name):

  currentframe = 0

  while(True):

      # reading from frame
      ret,frame = video.read()

      if ret:
          # if video is still left continue creating images
          name = './data/'+ path_name +'/frame'+ str(currentframe) + '.jpg'
          try:
        # creating a folder named data
            if not os.path.exists('./data/'+ path_name + '/frame'):
                os.makedirs('./data/'+ path_name + '/frame')

        # if not created then raise error
          except OSError:
              print ('Error: Creating directory of data')
          print ('Creating...' + name)

          # writing the extracted images
          cv2.imwrite(name, frame)

          # increasing counter so that it will
          # show how many frames are created
          currentframe += 1
      else:
          break

  # Release all space and windows once done
  video.release()
  cv2.destroyAllWindows()

# %%
videoFrameExtract(capture1,'video1')
videoFrameExtract(capture2,'video2')
videoFrameExtract(capture3,'video_long')
# Out:
# Streaming output truncated to the last 5000 lines.
# Creating..../data/video_long/frame447.jpg
# Creating..../data/video_long/frame448.jpg
# Creating..../data/video_long/frame449.jpg
# Creating..../data/video_long/frame450.jpg
# Creating..../data/video_long/frame451.jpg
# Creating..../data/video_long/frame452.jpg
# Creating..../data/video_long/frame453.jpg
# Creating..../data/video_long/frame454.jpg
# Creating..../data/video_long/frame455.jpg
# Creating..../data/video_long/frame456.jpg
# Creating..../data/video_long/frame457.jpg
# Creating..../data/video_long/frame458.jpg
# Creating..../data/video_long/frame459.jpg
# Creating..../data/video_long/frame460.jpg
# Creating..../data/video_long/frame461.jpg
# Creating..../data/video_long/frame462.jpg
# Creating..../data/video_long/frame463.jpg
# Creating..../data/video_long/frame464.jpg
# Creating..../data/video_long/frame465.jpg
# Creating..../data/video_long/frame466.jpg
# Creating..../data/video_long/frame467.jpg
# Creating..../data/video_long/frame468.jpg
# Creating..../data/video_long/frame469.jpg
# Creating..../data/video_long/frame470.jpg
# Creating..../data/video_long/frame471.jpg
# Creating..../data/video_long/frame472.jpg
# Creating..../data/video_long/frame473.jpg
# Creating..../data/video_long/frame474.jpg
# Creating..../data/video_long/frame475.jpg
# Creating..../data/video_long/frame476.jpg
# Creating..../data/video_long/frame477.jpg
# Creating..../data/video_long/frame478.jpg
# Creating..../data/video_long/frame479.jpg
# Creating..../data/video_long/frame480.jpg
# Creating..../data/video_long/frame481.jpg
# Creating..../data/video_long/frame482.jpg
# Creating..../data/video_long/frame483.jpg
# Creating..../data/video_long/frame484.jpg
# Creating..../data/video_long/frame485.jpg
# Creating..../data/video_long/frame486.jpg
# Creating..../data/video_long/frame487.jpg
# Creating..../data/video_long/frame488.jpg
# Creating..../data/video_long/frame489.jpg
# Creating..../data/video_long/frame490.jpg
# Creating..../data/video_long/frame491.jpg
# Creating..../data/video_long/frame492.jpg
# Creating..../data/video_long/frame493.jpg
# Creating..../data/video_long/frame494.jpg
# Creating..../data/video_long/frame495.jpg
# Creating..../data/video_long/frame496.jpg
# Creating..../data/video_long/frame497.jpg
# Creating..../data/video_long/frame498.jpg
# Creating..../data/video_long/frame499.jpg
# Creating..../data/video_long/frame500.jpg
# Creating..../data/video_long/frame501.jpg
# Creating..../data/video_long/frame502.jpg
# Creating..../data/video_long/frame503.jpg
# Creating..../data/video_long/frame504.jpg
# Creating..../data/video_long/frame505.jpg
# Creating..../data/video_long/frame506.jpg
# Creating..../data/video_long/frame507.jpg
# Creating..../data/video_long/frame508.jpg
# Creating..../data/video_long/frame509.jpg
# Creating..../data/video_long/frame510.jpg
# Creating..../data/video_long/frame511.jpg
# Creating..../data/video_long/frame512.jpg
# Creating..../data/video_long/frame513.jpg
# Creating..../data/video_long/frame514.jpg
# Creating..../data/video_long/frame515.jpg
# Creating..../data/video_long/frame516.jpg
# Creating..../data/video_long/frame517.jpg
# Creating..../data/video_long/frame518.jpg
# Creating..../data/video_long/frame519.jpg
# Creating..../data/video_long/frame520.jpg
# Creating..../data/video_long/frame521.jpg
# Creating..../data/video_long/frame522.jpg
# Creating..../data/video_long/frame523.jpg
# Creating..../data/video_long/frame524.jpg
# Creating..../data/video_long/frame525.jpg
# Creating..../data/video_long/frame526.jpg
# Creating..../data/video_long/frame527.jpg
# Creating..../data/video_long/frame528.jpg
# Creating..../data/video_long/frame529.jpg
# Creating..../data/video_long/frame530.jpg
# Creating..../data/video_long/frame531.jpg
# Creating..../data/video_long/frame532.jpg
# Creating..../data/video_long/frame533.jpg
# Creating..../data/video_long/frame534.jpg
# Creating..../data/video_long/frame535.jpg
# Creating..../data/video_long/frame536.jpg
# Creating..../data/video_long/frame537.jpg
# Creating..../data/video_long/frame538.jpg
# Creating..../data/video_long/frame539.jpg
# Creating..../data/video_long/frame540.jpg
# Creating..../data/video_long/frame541.jpg
# Creating..../data/video_long/frame542.jpg
# Creating..../data/video_long/frame543.jpg
# Creating..../data/video_long/frame544.jpg
# Creating..../data/video_long/frame545.jpg
# Creating..../data/video_long/frame546.jpg
# Creating..../data/video_long/frame547.jpg
# Creating..../data/video_long/frame548.jpg
# Creating..../data/video_long/frame549.jpg
# Creating..../data/video_long/frame550.jpg
# Creating..../data/video_long/frame551.jpg
# Creating..../data/video_long/frame552.jpg
# Creating..../data/video_long/frame553.jpg
# Creating..../data/video_long/frame554.jpg
# Creating..../data/video_long/frame555.jpg
# Creating..../data/video_long/frame556.jpg
# Creating..../data/video_long/frame557.jpg
# Creating..../data/video_long/frame558.jpg
# Creating..../data/video_long/frame559.jpg
# Creating..../data/video_long/frame560.jpg
# Creating..../data/video_long/frame561.jpg
# Creating..../data/video_long/frame562.jpg
# Creating..../data/video_long/frame563.jpg
# Creating..../data/video_long/frame564.jpg
# Creating..../data/video_long/frame565.jpg
# Creating..../data/video_long/frame566.jpg
# Creating..../data/video_long/frame567.jpg
# Creating..../data/video_long/frame568.jpg
# Creating..../data/video_long/frame569.jpg
# Creating..../data/video_long/frame570.jpg
# Creating..../data/video_long/frame571.jpg
# Creating..../data/video_long/frame572.jpg
# Creating..../data/video_long/frame573.jpg
# Creating..../data/video_long/frame574.jpg
# Creating..../data/video_long/frame575.jpg
# Creating..../data/video_long/frame576.jpg
# Creating..../data/video_long/frame577.jpg
# Creating..../data/video_long/frame578.jpg
# Creating..../data/video_long/frame579.jpg
# Creating..../data/video_long/frame580.jpg
# Creating..../data/video_long/frame581.jpg
# Creating..../data/video_long/frame582.jpg
# Creating..../data/video_long/frame583.jpg
# Creating..../data/video_long/frame584.jpg
# Creating..../data/video_long/frame585.jpg
# Creating..../data/video_long/frame586.jpg
# Creating..../data/video_long/frame587.jpg
# Creating..../data/video_long/frame588.jpg
# Creating..../data/video_long/frame589.jpg
# Creating..../data/video_long/frame590.jpg
# Creating..../data/video_long/frame591.jpg
# Creating..../data/video_long/frame592.jpg
# Creating..../data/video_long/frame593.jpg
# Creating..../data/video_long/frame594.jpg
# Creating..../data/video_long/frame595.jpg
# Creating..../data/video_long/frame596.jpg
# Creating..../data/video_long/frame597.jpg
# Creating..../data/video_long/frame598.jpg
# Creating..../data/video_long/frame599.jpg
# Creating..../data/video_long/frame600.jpg
# Creating..../data/video_long/frame601.jpg
# Creating..../data/video_long/frame602.jpg
# Creating..../data/video_long/frame603.jpg
# Creating..../data/video_long/frame604.jpg
# Creating..../data/video_long/frame605.jpg
# Creating..../data/video_long/frame606.jpg
# Creating..../data/video_long/frame607.jpg
# Creating..../data/video_long/frame608.jpg
# Creating..../data/video_long/frame609.jpg
# Creating..../data/video_long/frame610.jpg
# Creating..../data/video_long/frame611.jpg
# Creating..../data/video_long/frame612.jpg
# Creating..../data/video_long/frame613.jpg
# Creating..../data/video_long/frame614.jpg
# Creating..../data/video_long/frame615.jpg
# Creating..../data/video_long/frame616.jpg
# Creating..../data/video_long/frame617.jpg
# Creating..../data/video_long/frame618.jpg
# Creating..../data/video_long/frame619.jpg
# Creating..../data/video_long/frame620.jpg
# Creating..../data/video_long/frame621.jpg
# Creating..../data/video_long/frame622.jpg
# Creating..../data/video_long/frame623.jpg
# Creating..../data/video_long/frame624.jpg
# Creating..../data/video_long/frame625.jpg
# Creating..../data/video_long/frame626.jpg
# Creating..../data/video_long/frame627.jpg
# Creating..../data/video_long/frame628.jpg
# Creating..../data/video_long/frame629.jpg
# Creating..../data/video_long/frame630.jpg
# Creating..../data/video_long/frame631.jpg
# Creating..../data/video_long/frame632.jpg
# Creating..../data/video_long/frame633.jpg
# Creating..../data/video_long/frame634.jpg
# Creating..../data/video_long/frame635.jpg
# Creating..../data/video_long/frame636.jpg
# Creating..../data/video_long/frame637.jpg
# Creating..../data/video_long/frame638.jpg
# Creating..../data/video_long/frame639.jpg
# Creating..../data/video_long/frame640.jpg
# Creating..../data/video_long/frame641.jpg
# Creating..../data/video_long/frame642.jpg
# Creating..../data/video_long/frame643.jpg
# Creating..../data/video_long/frame644.jpg
# Creating..../data/video_long/frame645.jpg
# Creating..../data/video_long/frame646.jpg
# Creating..../data/video_long/frame647.jpg
# Creating..../data/video_long/frame648.jpg
# Creating..../data/video_long/frame649.jpg
# Creating..../data/video_long/frame650.jpg
# Creating..../data/video_long/frame651.jpg
# Creating..../data/video_long/frame652.jpg
# Creating..../data/video_long/frame653.jpg
# Creating..../data/video_long/frame654.jpg
# Creating..../data/video_long/frame655.jpg
# Creating..../data/video_long/frame656.jpg
# Creating..../data/video_long/frame657.jpg
# Creating..../data/video_long/frame658.jpg
# Creating..../data/video_long/frame659.jpg
# Creating..../data/video_long/frame660.jpg
# Creating..../data/video_long/frame661.jpg
# Creating..../data/video_long/frame662.jpg
# Creating..../data/video_long/frame663.jpg
# Creating..../data/video_long/frame664.jpg
# Creating..../data/video_long/frame665.jpg
# Creating..../data/video_long/frame666.jpg
# Creating..../data/video_long/frame667.jpg
# Creating..../data/video_long/frame668.jpg
# Creating..../data/video_long/frame669.jpg
# Creating..../data/video_long/frame670.jpg
# Creating..../data/video_long/frame671.jpg
# Creating..../data/video_long/frame672.jpg
# Creating..../data/video_long/frame673.jpg
# Creating..../data/video_long/frame674.jpg
# Creating..../data/video_long/frame675.jpg
# Creating..../data/video_long/frame676.jpg
# Creating..../data/video_long/frame677.jpg
# Creating..../data/video_long/frame678.jpg
# Creating..../data/video_long/frame679.jpg
# Creating..../data/video_long/frame680.jpg
# Creating..../data/video_long/frame681.jpg
# Creating..../data/video_long/frame682.jpg
# Creating..../data/video_long/frame683.jpg
# Creating..../data/video_long/frame684.jpg
# Creating..../data/video_long/frame685.jpg
# Creating..../data/video_long/frame686.jpg
# Creating..../data/video_long/frame687.jpg
# Creating..../data/video_long/frame688.jpg
# Creating..../data/video_long/frame689.jpg
# Creating..../data/video_long/frame690.jpg
# Creating..../data/video_long/frame691.jpg
# Creating..../data/video_long/frame692.jpg
# Creating..../data/video_long/frame693.jpg
# Creating..../data/video_long/frame694.jpg
# Creating..../data/video_long/frame695.jpg
# Creating..../data/video_long/frame696.jpg
# Creating..../data/video_long/frame697.jpg
# Creating..../data/video_long/frame698.jpg
# Creating..../data/video_long/frame699.jpg
# Creating..../data/video_long/frame700.jpg
# Creating..../data/video_long/frame701.jpg
# Creating..../data/video_long/frame702.jpg
# Creating..../data/video_long/frame703.jpg
# Creating..../data/video_long/frame704.jpg
# Creating..../data/video_long/frame705.jpg
# Creating..../data/video_long/frame706.jpg
# Creating..../data/video_long/frame707.jpg
# Creating..../data/video_long/frame708.jpg
# Creating..../data/video_long/frame709.jpg
# Creating..../data/video_long/frame710.jpg
# Creating..../data/video_long/frame711.jpg
# Creating..../data/video_long/frame712.jpg
# Creating..../data/video_long/frame713.jpg
# Creating..../data/video_long/frame714.jpg
# Creating..../data/video_long/frame715.jpg
# Creating..../data/video_long/frame716.jpg
# Creating..../data/video_long/frame717.jpg
# Creating..../data/video_long/frame718.jpg
# Creating..../data/video_long/frame719.jpg
# Creating..../data/video_long/frame720.jpg
# Creating..../data/video_long/frame721.jpg
# Creating..../data/video_long/frame722.jpg
# Creating..../data/video_long/frame723.jpg
# Creating..../data/video_long/frame724.jpg
# Creating..../data/video_long/frame725.jpg
# Creating..../data/video_long/frame726.jpg
# Creating..../data/video_long/frame727.jpg
# Creating..../data/video_long/frame728.jpg
# Creating..../data/video_long/frame729.jpg
# Creating..../data/video_long/frame730.jpg
# Creating..../data/video_long/frame731.jpg
# Creating..../data/video_long/frame732.jpg
# Creating..../data/video_long/frame733.jpg
# Creating..../data/video_long/frame734.jpg
# Creating..../data/video_long/frame735.jpg
# Creating..../data/video_long/frame736.jpg
# Creating..../data/video_long/frame737.jpg
# Creating..../data/video_long/frame738.jpg
# Creating..../data/video_long/frame739.jpg
# Creating..../data/video_long/frame740.jpg
# Creating..../data/video_long/frame741.jpg
# Creating..../data/video_long/frame742.jpg
# Creating..../data/video_long/frame743.jpg
# Creating..../data/video_long/frame744.jpg
# Creating..../data/video_long/frame745.jpg
# Creating..../data/video_long/frame746.jpg
# Creating..../data/video_long/frame747.jpg
# Creating..../data/video_long/frame748.jpg
# Creating..../data/video_long/frame749.jpg
# Creating..../data/video_long/frame750.jpg
# Creating..../data/video_long/frame751.jpg
# Creating..../data/video_long/frame752.jpg
# Creating..../data/video_long/frame753.jpg
# Creating..../data/video_long/frame754.jpg
# Creating..../data/video_long/frame755.jpg
# Creating..../data/video_long/frame756.jpg
# Creating..../data/video_long/frame757.jpg
# Creating..../data/video_long/frame758.jpg
# Creating..../data/video_long/frame759.jpg
# Creating..../data/video_long/frame760.jpg
# Creating..../data/video_long/frame761.jpg
# Creating..../data/video_long/frame762.jpg
# Creating..../data/video_long/frame763.jpg
# Creating..../data/video_long/frame764.jpg
# Creating..../data/video_long/frame765.jpg
# Creating..../data/video_long/frame766.jpg
# Creating..../data/video_long/frame767.jpg
# Creating..../data/video_long/frame768.jpg
# Creating..../data/video_long/frame769.jpg
# Creating..../data/video_long/frame770.jpg
# Creating..../data/video_long/frame771.jpg
# Creating..../data/video_long/frame772.jpg
# Creating..../data/video_long/frame773.jpg
# Creating..../data/video_long/frame774.jpg
# Creating..../data/video_long/frame775.jpg
# Creating..../data/video_long/frame776.jpg
# Creating..../data/video_long/frame777.jpg
# Creating..../data/video_long/frame778.jpg
# Creating..../data/video_long/frame779.jpg
# Creating..../data/video_long/frame780.jpg
# Creating..../data/video_long/frame781.jpg
# Creating..../data/video_long/frame782.jpg
# Creating..../data/video_long/frame783.jpg
# Creating..../data/video_long/frame784.jpg
# Creating..../data/video_long/frame785.jpg
# Creating..../data/video_long/frame786.jpg
# Creating..../data/video_long/frame787.jpg
# Creating..../data/video_long/frame788.jpg
# Creating..../data/video_long/frame789.jpg
# Creating..../data/video_long/frame790.jpg
# Creating..../data/video_long/frame791.jpg
# Creating..../data/video_long/frame792.jpg
# Creating..../data/video_long/frame793.jpg
# Creating..../data/video_long/frame794.jpg
# Creating..../data/video_long/frame795.jpg
# Creating..../data/video_long/frame796.jpg
# Creating..../data/video_long/frame797.jpg
# Creating..../data/video_long/frame798.jpg
# Creating..../data/video_long/frame799.jpg
# Creating..../data/video_long/frame800.jpg
# Creating..../data/video_long/frame801.jpg
# Creating..../data/video_long/frame802.jpg
# Creating..../data/video_long/frame803.jpg
# Creating..../data/video_long/frame804.jpg
# Creating..../data/video_long/frame805.jpg
# Creating..../data/video_long/frame806.jpg
# Creating..../data/video_long/frame807.jpg
# Creating..../data/video_long/frame808.jpg
# Creating..../data/video_long/frame809.jpg
# Creating..../data/video_long/frame810.jpg
# Creating..../data/video_long/frame811.jpg
# Creating..../data/video_long/frame812.jpg
# Creating..../data/video_long/frame813.jpg
# Creating..../data/video_long/frame814.jpg
# Creating..../data/video_long/frame815.jpg
# Creating..../data/video_long/frame816.jpg
# Creating..../data/video_long/frame817.jpg
# Creating..../data/video_long/frame818.jpg
# Creating..../data/video_long/frame819.jpg
# Creating..../data/video_long/frame820.jpg
# Creating..../data/video_long/frame821.jpg
# Creating..../data/video_long/frame822.jpg
# Creating..../data/video_long/frame823.jpg
# Creating..../data/video_long/frame824.jpg
# Creating..../data/video_long/frame825.jpg
# Creating..../data/video_long/frame826.jpg
# Creating..../data/video_long/frame827.jpg
# Creating..../data/video_long/frame828.jpg
# Creating..../data/video_long/frame829.jpg
# Creating..../data/video_long/frame830.jpg
# Creating..../data/video_long/frame831.jpg
# Creating..../data/video_long/frame832.jpg
# Creating..../data/video_long/frame833.jpg
# Creating..../data/video_long/frame834.jpg
# Creating..../data/video_long/frame835.jpg
# Creating..../data/video_long/frame836.jpg
# Creating..../data/video_long/frame837.jpg
# Creating..../data/video_long/frame838.jpg
# Creating..../data/video_long/frame839.jpg
# Creating..../data/video_long/frame840.jpg
# Creating..../data/video_long/frame841.jpg
# Creating..../data/video_long/frame842.jpg
# Creating..../data/video_long/frame843.jpg
# Creating..../data/video_long/frame844.jpg
# Creating..../data/video_long/frame845.jpg
# Creating..../data/video_long/frame846.jpg
# Creating..../data/video_long/frame847.jpg
# Creating..../data/video_long/frame848.jpg
# Creating..../data/video_long/frame849.jpg
# Creating..../data/video_long/frame850.jpg
# Creating..../data/video_long/frame851.jpg
# Creating..../data/video_long/frame852.jpg
# Creating..../data/video_long/frame853.jpg
# Creating..../data/video_long/frame854.jpg
# Creating..../data/video_long/frame855.jpg
# Creating..../data/video_long/frame856.jpg
# Creating..../data/video_long/frame857.jpg
# Creating..../data/video_long/frame858.jpg
# Creating..../data/video_long/frame859.jpg
# Creating..../data/video_long/frame860.jpg
# Creating..../data/video_long/frame861.jpg
# Creating..../data/video_long/frame862.jpg
# Creating..../data/video_long/frame863.jpg
# Creating..../data/video_long/frame864.jpg
# Creating..../data/video_long/frame865.jpg
# Creating..../data/video_long/frame866.jpg
# Creating..../data/video_long/frame867.jpg
# Creating..../data/video_long/frame868.jpg
# Creating..../data/video_long/frame869.jpg
# Creating..../data/video_long/frame870.jpg
# Creating..../data/video_long/frame871.jpg
# Creating..../data/video_long/frame872.jpg
# Creating..../data/video_long/frame873.jpg
# Creating..../data/video_long/frame874.jpg
# Creating..../data/video_long/frame875.jpg
# Creating..../data/video_long/frame876.jpg
# Creating..../data/video_long/frame877.jpg
# Creating..../data/video_long/frame878.jpg
# Creating..../data/video_long/frame879.jpg
# Creating..../data/video_long/frame880.jpg
# Creating..../data/video_long/frame881.jpg
# Creating..../data/video_long/frame882.jpg
# Creating..../data/video_long/frame883.jpg
# Creating..../data/video_long/frame884.jpg
# Creating..../data/video_long/frame885.jpg
# Creating..../data/video_long/frame886.jpg
# Creating..../data/video_long/frame887.jpg
# Creating..../data/video_long/frame888.jpg
# Creating..../data/video_long/frame889.jpg
# Creating..../data/video_long/frame890.jpg
# Creating..../data/video_long/frame891.jpg
# Creating..../data/video_long/frame892.jpg
# Creating..../data/video_long/frame893.jpg
# Creating..../data/video_long/frame894.jpg
# Creating..../data/video_long/frame895.jpg
# Creating..../data/video_long/frame896.jpg
# Creating..../data/video_long/frame897.jpg
# Creating..../data/video_long/frame898.jpg
# Creating..../data/video_long/frame899.jpg
# Creating..../data/video_long/frame900.jpg
# Creating..../data/video_long/frame901.jpg
# Creating..../data/video_long/frame902.jpg
# Creating..../data/video_long/frame903.jpg
# Creating..../data/video_long/frame904.jpg
# Creating..../data/video_long/frame905.jpg
# Creating..../data/video_long/frame906.jpg
# Creating..../data/video_long/frame907.jpg
# Creating..../data/video_long/frame908.jpg
# Creating..../data/video_long/frame909.jpg
# Creating..../data/video_long/frame910.jpg
# Creating..../data/video_long/frame911.jpg
# Creating..../data/video_long/frame912.jpg
# Creating..../data/video_long/frame913.jpg
# Creating..../data/video_long/frame914.jpg
# Creating..../data/video_long/frame915.jpg
# Creating..../data/video_long/frame916.jpg
# Creating..../data/video_long/frame917.jpg
# Creating..../data/video_long/frame918.jpg
# Creating..../data/video_long/frame919.jpg
# Creating..../data/video_long/frame920.jpg
# Creating..../data/video_long/frame921.jpg
# Creating..../data/video_long/frame922.jpg
# Creating..../data/video_long/frame923.jpg
# Creating..../data/video_long/frame924.jpg
# Creating..../data/video_long/frame925.jpg
# Creating..../data/video_long/frame926.jpg
# Creating..../data/video_long/frame927.jpg
# Creating..../data/video_long/frame928.jpg
# Creating..../data/video_long/frame929.jpg
# Creating..../data/video_long/frame930.jpg
# Creating..../data/video_long/frame931.jpg
# Creating..../data/video_long/frame932.jpg
# Creating..../data/video_long/frame933.jpg
# Creating..../data/video_long/frame934.jpg
# Creating..../data/video_long/frame935.jpg
# Creating..../data/video_long/frame936.jpg
# Creating..../data/video_long/frame937.jpg
# Creating..../data/video_long/frame938.jpg
# Creating..../data/video_long/frame939.jpg
# Creating..../data/video_long/frame940.jpg
# Creating..../data/video_long/frame941.jpg
# Creating..../data/video_long/frame942.jpg
# Creating..../data/video_long/frame943.jpg
# Creating..../data/video_long/frame944.jpg
# Creating..../data/video_long/frame945.jpg
# Creating..../data/video_long/frame946.jpg
# Creating..../data/video_long/frame947.jpg
# Creating..../data/video_long/frame948.jpg
# Creating..../data/video_long/frame949.jpg
# Creating..../data/video_long/frame950.jpg
# Creating..../data/video_long/frame951.jpg
# Creating..../data/video_long/frame952.jpg
# Creating..../data/video_long/frame953.jpg
# Creating..../data/video_long/frame954.jpg
# Creating..../data/video_long/frame955.jpg
# Creating..../data/video_long/frame956.jpg
# Creating..../data/video_long/frame957.jpg
# Creating..../data/video_long/frame958.jpg
# Creating..../data/video_long/frame959.jpg
# Creating..../data/video_long/frame960.jpg
# Creating..../data/video_long/frame961.jpg
# Creating..../data/video_long/frame962.jpg
# Creating..../data/video_long/frame963.jpg
# Creating..../data/video_long/frame964.jpg
# Creating..../data/video_long/frame965.jpg
# Creating..../data/video_long/frame966.jpg
# Creating..../data/video_long/frame967.jpg
# Creating..../data/video_long/frame968.jpg
# Creating..../data/video_long/frame969.jpg
# Creating..../data/video_long/frame970.jpg
# Creating..../data/video_long/frame971.jpg
# Creating..../data/video_long/frame972.jpg
# Creating..../data/video_long/frame973.jpg
# Creating..../data/video_long/frame974.jpg
# Creating..../data/video_long/frame975.jpg
# Creating..../data/video_long/frame976.jpg
# Creating..../data/video_long/frame977.jpg
# Creating..../data/video_long/frame978.jpg
# Creating..../data/video_long/frame979.jpg
# Creating..../data/video_long/frame980.jpg
# Creating..../data/video_long/frame981.jpg
# Creating..../data/video_long/frame982.jpg
# Creating..../data/video_long/frame983.jpg
# Creating..../data/video_long/frame984.jpg
# Creating..../data/video_long/frame985.jpg
# Creating..../data/video_long/frame986.jpg
# Creating..../data/video_long/frame987.jpg
# Creating..../data/video_long/frame988.jpg
# Creating..../data/video_long/frame989.jpg
# Creating..../data/video_long/frame990.jpg
# Creating..../data/video_long/frame991.jpg
# Creating..../data/video_long/frame992.jpg
# Creating..../data/video_long/frame993.jpg
# Creating..../data/video_long/frame994.jpg
# Creating..../data/video_long/frame995.jpg
# Creating..../data/video_long/frame996.jpg
# Creating..../data/video_long/frame997.jpg
# Creating..../data/video_long/frame998.jpg
# Creating..../data/video_long/frame999.jpg
# Creating..../data/video_long/frame1000.jpg
# Creating..../data/video_long/frame1001.jpg
# Creating..../data/video_long/frame1002.jpg
# Creating..../data/video_long/frame1003.jpg
# Creating..../data/video_long/frame1004.jpg
# Creating..../data/video_long/frame1005.jpg
# Creating..../data/video_long/frame1006.jpg
# Creating..../data/video_long/frame1007.jpg
# Creating..../data/video_long/frame1008.jpg
# Creating..../data/video_long/frame1009.jpg
# Creating..../data/video_long/frame1010.jpg
# Creating..../data/video_long/frame1011.jpg
# Creating..../data/video_long/frame1012.jpg
# Creating..../data/video_long/frame1013.jpg
# Creating..../data/video_long/frame1014.jpg
# Creating..../data/video_long/frame1015.jpg
# Creating..../data/video_long/frame1016.jpg
# Creating..../data/video_long/frame1017.jpg
# Creating..../data/video_long/frame1018.jpg
# Creating..../data/video_long/frame1019.jpg
# Creating..../data/video_long/frame1020.jpg
# Creating..../data/video_long/frame1021.jpg
# Creating..../data/video_long/frame1022.jpg
# Creating..../data/video_long/frame1023.jpg
# Creating..../data/video_long/frame1024.jpg
# Creating..../data/video_long/frame1025.jpg
# Creating..../data/video_long/frame1026.jpg
# Creating..../data/video_long/frame1027.jpg
# Creating..../data/video_long/frame1028.jpg
# Creating..../data/video_long/frame1029.jpg
# Creating..../data/video_long/frame1030.jpg
# Creating..../data/video_long/frame1031.jpg
# Creating..../data/video_long/frame1032.jpg
# Creating..../data/video_long/frame1033.jpg
# Creating..../data/video_long/frame1034.jpg
# Creating..../data/video_long/frame1035.jpg
# Creating..../data/video_long/frame1036.jpg
# Creating..../data/video_long/frame1037.jpg
# Creating..../data/video_long/frame1038.jpg
# Creating..../data/video_long/frame1039.jpg
# Creating..../data/video_long/frame1040.jpg
# Creating..../data/video_long/frame1041.jpg
# Creating..../data/video_long/frame1042.jpg
# Creating..../data/video_long/frame1043.jpg
# Creating..../data/video_long/frame1044.jpg
# Creating..../data/video_long/frame1045.jpg
# Creating..../data/video_long/frame1046.jpg
# Creating..../data/video_long/frame1047.jpg
# Creating..../data/video_long/frame1048.jpg
# Creating..../data/video_long/frame1049.jpg
# Creating..../data/video_long/frame1050.jpg
# Creating..../data/video_long/frame1051.jpg
# Creating..../data/video_long/frame1052.jpg
# Creating..../data/video_long/frame1053.jpg
# Creating..../data/video_long/frame1054.jpg
# Creating..../data/video_long/frame1055.jpg
# Creating..../data/video_long/frame1056.jpg
# Creating..../data/video_long/frame1057.jpg
# Creating..../data/video_long/frame1058.jpg
# Creating..../data/video_long/frame1059.jpg
# Creating..../data/video_long/frame1060.jpg
# Creating..../data/video_long/frame1061.jpg
# Creating..../data/video_long/frame1062.jpg
# Creating..../data/video_long/frame1063.jpg
# Creating..../data/video_long/frame1064.jpg
# Creating..../data/video_long/frame1065.jpg
# Creating..../data/video_long/frame1066.jpg
# Creating..../data/video_long/frame1067.jpg
# Creating..../data/video_long/frame1068.jpg
# Creating..../data/video_long/frame1069.jpg
# Creating..../data/video_long/frame1070.jpg
# Creating..../data/video_long/frame1071.jpg
# Creating..../data/video_long/frame1072.jpg
# Creating..../data/video_long/frame1073.jpg
# Creating..../data/video_long/frame1074.jpg
# Creating..../data/video_long/frame1075.jpg
# Creating..../data/video_long/frame1076.jpg
# Creating..../data/video_long/frame1077.jpg
# Creating..../data/video_long/frame1078.jpg
# Creating..../data/video_long/frame1079.jpg
# Creating..../data/video_long/frame1080.jpg
# Creating..../data/video_long/frame1081.jpg
# Creating..../data/video_long/frame1082.jpg
# Creating..../data/video_long/frame1083.jpg
# Creating..../data/video_long/frame1084.jpg
# Creating..../data/video_long/frame1085.jpg
# Creating..../data/video_long/frame1086.jpg
# Creating..../data/video_long/frame1087.jpg
# Creating..../data/video_long/frame1088.jpg
# Creating..../data/video_long/frame1089.jpg
# Creating..../data/video_long/frame1090.jpg
# Creating..../data/video_long/frame1091.jpg
# Creating..../data/video_long/frame1092.jpg
# Creating..../data/video_long/frame1093.jpg
# Creating..../data/video_long/frame1094.jpg
# Creating..../data/video_long/frame1095.jpg
# Creating..../data/video_long/frame1096.jpg
# Creating..../data/video_long/frame1097.jpg
# Creating..../data/video_long/frame1098.jpg
# Creating..../data/video_long/frame1099.jpg
# Creating..../data/video_long/frame1100.jpg
# Creating..../data/video_long/frame1101.jpg
# Creating..../data/video_long/frame1102.jpg
# Creating..../data/video_long/frame1103.jpg
# Creating..../data/video_long/frame1104.jpg
# Creating..../data/video_long/frame1105.jpg
# Creating..../data/video_long/frame1106.jpg
# Creating..../data/video_long/frame1107.jpg
# Creating..../data/video_long/frame1108.jpg
# Creating..../data/video_long/frame1109.jpg
# Creating..../data/video_long/frame1110.jpg
# Creating..../data/video_long/frame1111.jpg
# Creating..../data/video_long/frame1112.jpg
# Creating..../data/video_long/frame1113.jpg
# Creating..../data/video_long/frame1114.jpg
# Creating..../data/video_long/frame1115.jpg
# Creating..../data/video_long/frame1116.jpg
# Creating..../data/video_long/frame1117.jpg
# Creating..../data/video_long/frame1118.jpg
# Creating..../data/video_long/frame1119.jpg
# Creating..../data/video_long/frame1120.jpg
# Creating..../data/video_long/frame1121.jpg
# Creating..../data/video_long/frame1122.jpg
# Creating..../data/video_long/frame1123.jpg
# Creating..../data/video_long/frame1124.jpg
# Creating..../data/video_long/frame1125.jpg
# Creating..../data/video_long/frame1126.jpg
# Creating..../data/video_long/frame1127.jpg
# Creating..../data/video_long/frame1128.jpg
# Creating..../data/video_long/frame1129.jpg
# Creating..../data/video_long/frame1130.jpg
# Creating..../data/video_long/frame1131.jpg
# Creating..../data/video_long/frame1132.jpg
# Creating..../data/video_long/frame1133.jpg
# Creating..../data/video_long/frame1134.jpg
# Creating..../data/video_long/frame1135.jpg
# Creating..../data/video_long/frame1136.jpg
# Creating..../data/video_long/frame1137.jpg
# Creating..../data/video_long/frame1138.jpg
# Creating..../data/video_long/frame1139.jpg
# Creating..../data/video_long/frame1140.jpg
# Creating..../data/video_long/frame1141.jpg
# Creating..../data/video_long/frame1142.jpg
# Creating..../data/video_long/frame1143.jpg
# Creating..../data/video_long/frame1144.jpg
# Creating..../data/video_long/frame1145.jpg
# Creating..../data/video_long/frame1146.jpg
# Creating..../data/video_long/frame1147.jpg
# Creating..../data/video_long/frame1148.jpg
# Creating..../data/video_long/frame1149.jpg
# Creating..../data/video_long/frame1150.jpg
# Creating..../data/video_long/frame1151.jpg
# Creating..../data/video_long/frame1152.jpg
# Creating..../data/video_long/frame1153.jpg
# Creating..../data/video_long/frame1154.jpg
# Creating..../data/video_long/frame1155.jpg
# Creating..../data/video_long/frame1156.jpg
# Creating..../data/video_long/frame1157.jpg
# Creating..../data/video_long/frame1158.jpg
# Creating..../data/video_long/frame1159.jpg
# Creating..../data/video_long/frame1160.jpg
# Creating..../data/video_long/frame1161.jpg
# Creating..../data/video_long/frame1162.jpg
# Creating..../data/video_long/frame1163.jpg
# Creating..../data/video_long/frame1164.jpg
# Creating..../data/video_long/frame1165.jpg
# Creating..../data/video_long/frame1166.jpg
# Creating..../data/video_long/frame1167.jpg
# Creating..../data/video_long/frame1168.jpg
# Creating..../data/video_long/frame1169.jpg
# Creating..../data/video_long/frame1170.jpg
# Creating..../data/video_long/frame1171.jpg
# Creating..../data/video_long/frame1172.jpg
# Creating..../data/video_long/frame1173.jpg
# Creating..../data/video_long/frame1174.jpg
# Creating..../data/video_long/frame1175.jpg
# Creating..../data/video_long/frame1176.jpg
# Creating..../data/video_long/frame1177.jpg
# Creating..../data/video_long/frame1178.jpg
# Creating..../data/video_long/frame1179.jpg
# Creating..../data/video_long/frame1180.jpg
# Creating..../data/video_long/frame1181.jpg
# Creating..../data/video_long/frame1182.jpg
# Creating..../data/video_long/frame1183.jpg
# Creating..../data/video_long/frame1184.jpg
# Creating..../data/video_long/frame1185.jpg
# Creating..../data/video_long/frame1186.jpg
# Creating..../data/video_long/frame1187.jpg
# Creating..../data/video_long/frame1188.jpg
# Creating..../data/video_long/frame1189.jpg
# Creating..../data/video_long/frame1190.jpg
# Creating..../data/video_long/frame1191.jpg
# Creating..../data/video_long/frame1192.jpg
# Creating..../data/video_long/frame1193.jpg
# Creating..../data/video_long/frame1194.jpg
# Creating..../data/video_long/frame1195.jpg
# Creating..../data/video_long/frame1196.jpg
# Creating..../data/video_long/frame1197.jpg
# Creating..../data/video_long/frame1198.jpg
# Creating..../data/video_long/frame1199.jpg
# Creating..../data/video_long/frame1200.jpg
# Creating..../data/video_long/frame1201.jpg
# Creating..../data/video_long/frame1202.jpg
# Creating..../data/video_long/frame1203.jpg
# Creating..../data/video_long/frame1204.jpg
# Creating..../data/video_long/frame1205.jpg
# Creating..../data/video_long/frame1206.jpg
# Creating..../data/video_long/frame1207.jpg
# Creating..../data/video_long/frame1208.jpg
# Creating..../data/video_long/frame1209.jpg
# Creating..../data/video_long/frame1210.jpg
# Creating..../data/video_long/frame1211.jpg
# Creating..../data/video_long/frame1212.jpg
# Creating..../data/video_long/frame1213.jpg
# Creating..../data/video_long/frame1214.jpg
# Creating..../data/video_long/frame1215.jpg
# Creating..../data/video_long/frame1216.jpg
# Creating..../data/video_long/frame1217.jpg
# Creating..../data/video_long/frame1218.jpg
# Creating..../data/video_long/frame1219.jpg
# Creating..../data/video_long/frame1220.jpg
# Creating..../data/video_long/frame1221.jpg
# Creating..../data/video_long/frame1222.jpg
# Creating..../data/video_long/frame1223.jpg
# Creating..../data/video_long/frame1224.jpg
# Creating..../data/video_long/frame1225.jpg
# Creating..../data/video_long/frame1226.jpg
# Creating..../data/video_long/frame1227.jpg
# Creating..../data/video_long/frame1228.jpg
# Creating..../data/video_long/frame1229.jpg
# Creating..../data/video_long/frame1230.jpg
# Creating..../data/video_long/frame1231.jpg
# Creating..../data/video_long/frame1232.jpg
# Creating..../data/video_long/frame1233.jpg
# Creating..../data/video_long/frame1234.jpg
# Creating..../data/video_long/frame1235.jpg
# Creating..../data/video_long/frame1236.jpg
# Creating..../data/video_long/frame1237.jpg
# Creating..../data/video_long/frame1238.jpg
# Creating..../data/video_long/frame1239.jpg
# Creating..../data/video_long/frame1240.jpg
# Creating..../data/video_long/frame1241.jpg
# Creating..../data/video_long/frame1242.jpg
# Creating..../data/video_long/frame1243.jpg
# Creating..../data/video_long/frame1244.jpg
# Creating..../data/video_long/frame1245.jpg
# Creating..../data/video_long/frame1246.jpg
# Creating..../data/video_long/frame1247.jpg
# Creating..../data/video_long/frame1248.jpg
# Creating..../data/video_long/frame1249.jpg
# Creating..../data/video_long/frame1250.jpg
# Creating..../data/video_long/frame1251.jpg
# Creating..../data/video_long/frame1252.jpg
# Creating..../data/video_long/frame1253.jpg
# Creating..../data/video_long/frame1254.jpg
# Creating..../data/video_long/frame1255.jpg
# Creating..../data/video_long/frame1256.jpg
# Creating..../data/video_long/frame1257.jpg
# Creating..../data/video_long/frame1258.jpg
# Creating..../data/video_long/frame1259.jpg
# Creating..../data/video_long/frame1260.jpg
# Creating..../data/video_long/frame1261.jpg
# Creating..../data/video_long/frame1262.jpg
# Creating..../data/video_long/frame1263.jpg
# Creating..../data/video_long/frame1264.jpg
# Creating..../data/video_long/frame1265.jpg
# Creating..../data/video_long/frame1266.jpg
# Creating..../data/video_long/frame1267.jpg
# Creating..../data/video_long/frame1268.jpg
# Creating..../data/video_long/frame1269.jpg
# Creating..../data/video_long/frame1270.jpg
# Creating..../data/video_long/frame1271.jpg
# Creating..../data/video_long/frame1272.jpg
# Creating..../data/video_long/frame1273.jpg
# Creating..../data/video_long/frame1274.jpg
# Creating..../data/video_long/frame1275.jpg
# Creating..../data/video_long/frame1276.jpg
# Creating..../data/video_long/frame1277.jpg
# Creating..../data/video_long/frame1278.jpg
# Creating..../data/video_long/frame1279.jpg
# Creating..../data/video_long/frame1280.jpg
# Creating..../data/video_long/frame1281.jpg
# Creating..../data/video_long/frame1282.jpg
# Creating..../data/video_long/frame1283.jpg
# Creating..../data/video_long/frame1284.jpg
# Creating..../data/video_long/frame1285.jpg
# Creating..../data/video_long/frame1286.jpg
# Creating..../data/video_long/frame1287.jpg
# Creating..../data/video_long/frame1288.jpg
# Creating..../data/video_long/frame1289.jpg
# Creating..../data/video_long/frame1290.jpg
# Creating..../data/video_long/frame1291.jpg
# Creating..../data/video_long/frame1292.jpg
# Creating..../data/video_long/frame1293.jpg
# Creating..../data/video_long/frame1294.jpg
# Creating..../data/video_long/frame1295.jpg
# Creating..../data/video_long/frame1296.jpg
# Creating..../data/video_long/frame1297.jpg
# Creating..../data/video_long/frame1298.jpg
# Creating..../data/video_long/frame1299.jpg
# Creating..../data/video_long/frame1300.jpg
# Creating..../data/video_long/frame1301.jpg
# Creating..../data/video_long/frame1302.jpg
# Creating..../data/video_long/frame1303.jpg
# Creating..../data/video_long/frame1304.jpg
# Creating..../data/video_long/frame1305.jpg
# Creating..../data/video_long/frame1306.jpg
# Creating..../data/video_long/frame1307.jpg
# Creating..../data/video_long/frame1308.jpg
# Creating..../data/video_long/frame1309.jpg
# Creating..../data/video_long/frame1310.jpg
# Creating..../data/video_long/frame1311.jpg
# Creating..../data/video_long/frame1312.jpg
# Creating..../data/video_long/frame1313.jpg
# Creating..../data/video_long/frame1314.jpg
# Creating..../data/video_long/frame1315.jpg
# Creating..../data/video_long/frame1316.jpg
# Creating..../data/video_long/frame1317.jpg
# Creating..../data/video_long/frame1318.jpg
# Creating..../data/video_long/frame1319.jpg
# Creating..../data/video_long/frame1320.jpg
# Creating..../data/video_long/frame1321.jpg
# Creating..../data/video_long/frame1322.jpg
# Creating..../data/video_long/frame1323.jpg
# Creating..../data/video_long/frame1324.jpg
# Creating..../data/video_long/frame1325.jpg
# Creating..../data/video_long/frame1326.jpg
# Creating..../data/video_long/frame1327.jpg
# Creating..../data/video_long/frame1328.jpg
# Creating..../data/video_long/frame1329.jpg
# Creating..../data/video_long/frame1330.jpg
# Creating..../data/video_long/frame1331.jpg
# Creating..../data/video_long/frame1332.jpg
# Creating..../data/video_long/frame1333.jpg
# Creating..../data/video_long/frame1334.jpg
# Creating..../data/video_long/frame1335.jpg
# Creating..../data/video_long/frame1336.jpg
# Creating..../data/video_long/frame1337.jpg
# Creating..../data/video_long/frame1338.jpg
# Creating..../data/video_long/frame1339.jpg
# Creating..../data/video_long/frame1340.jpg
# Creating..../data/video_long/frame1341.jpg
# Creating..../data/video_long/frame1342.jpg
# Creating..../data/video_long/frame1343.jpg
# Creating..../data/video_long/frame1344.jpg
# Creating..../data/video_long/frame1345.jpg
# Creating..../data/video_long/frame1346.jpg
# Creating..../data/video_long/frame1347.jpg
# Creating..../data/video_long/frame1348.jpg
# Creating..../data/video_long/frame1349.jpg
# Creating..../data/video_long/frame1350.jpg
# Creating..../data/video_long/frame1351.jpg
# Creating..../data/video_long/frame1352.jpg
# Creating..../data/video_long/frame1353.jpg
# Creating..../data/video_long/frame1354.jpg
# Creating..../data/video_long/frame1355.jpg
# Creating..../data/video_long/frame1356.jpg
# Creating..../data/video_long/frame1357.jpg
# Creating..../data/video_long/frame1358.jpg
# Creating..../data/video_long/frame1359.jpg
# Creating..../data/video_long/frame1360.jpg
# Creating..../data/video_long/frame1361.jpg
# Creating..../data/video_long/frame1362.jpg
# Creating..../data/video_long/frame1363.jpg
# Creating..../data/video_long/frame1364.jpg
# Creating..../data/video_long/frame1365.jpg
# Creating..../data/video_long/frame1366.jpg
# Creating..../data/video_long/frame1367.jpg
# Creating..../data/video_long/frame1368.jpg
# Creating..../data/video_long/frame1369.jpg
# Creating..../data/video_long/frame1370.jpg
# Creating..../data/video_long/frame1371.jpg
# Creating..../data/video_long/frame1372.jpg
# Creating..../data/video_long/frame1373.jpg
# Creating..../data/video_long/frame1374.jpg
# Creating..../data/video_long/frame1375.jpg
# Creating..../data/video_long/frame1376.jpg
# Creating..../data/video_long/frame1377.jpg
# Creating..../data/video_long/frame1378.jpg
# Creating..../data/video_long/frame1379.jpg
# Creating..../data/video_long/frame1380.jpg
# Creating..../data/video_long/frame1381.jpg
# Creating..../data/video_long/frame1382.jpg
# Creating..../data/video_long/frame1383.jpg
# Creating..../data/video_long/frame1384.jpg
# Creating..../data/video_long/frame1385.jpg
# Creating..../data/video_long/frame1386.jpg
# Creating..../data/video_long/frame1387.jpg
# Creating..../data/video_long/frame1388.jpg
# Creating..../data/video_long/frame1389.jpg
# Creating..../data/video_long/frame1390.jpg
# Creating..../data/video_long/frame1391.jpg
# Creating..../data/video_long/frame1392.jpg
# Creating..../data/video_long/frame1393.jpg
# Creating..../data/video_long/frame1394.jpg
# Creating..../data/video_long/frame1395.jpg
# Creating..../data/video_long/frame1396.jpg
# Creating..../data/video_long/frame1397.jpg
# Creating..../data/video_long/frame1398.jpg
# Creating..../data/video_long/frame1399.jpg
# Creating..../data/video_long/frame1400.jpg
# Creating..../data/video_long/frame1401.jpg
# Creating..../data/video_long/frame1402.jpg
# Creating..../data/video_long/frame1403.jpg
# Creating..../data/video_long/frame1404.jpg
# Creating..../data/video_long/frame1405.jpg
# Creating..../data/video_long/frame1406.jpg
# Creating..../data/video_long/frame1407.jpg
# Creating..../data/video_long/frame1408.jpg
# Creating..../data/video_long/frame1409.jpg
# Creating..../data/video_long/frame1410.jpg
# Creating..../data/video_long/frame1411.jpg
# Creating..../data/video_long/frame1412.jpg
# Creating..../data/video_long/frame1413.jpg
# Creating..../data/video_long/frame1414.jpg
# Creating..../data/video_long/frame1415.jpg
# Creating..../data/video_long/frame1416.jpg
# Creating..../data/video_long/frame1417.jpg
# Creating..../data/video_long/frame1418.jpg
# Creating..../data/video_long/frame1419.jpg
# Creating..../data/video_long/frame1420.jpg
# Creating..../data/video_long/frame1421.jpg
# Creating..../data/video_long/frame1422.jpg
# Creating..../data/video_long/frame1423.jpg
# Creating..../data/video_long/frame1424.jpg
# Creating..../data/video_long/frame1425.jpg
# Creating..../data/video_long/frame1426.jpg
# Creating..../data/video_long/frame1427.jpg
# Creating..../data/video_long/frame1428.jpg
# Creating..../data/video_long/frame1429.jpg
# Creating..../data/video_long/frame1430.jpg
# Creating..../data/video_long/frame1431.jpg
# Creating..../data/video_long/frame1432.jpg
# Creating..../data/video_long/frame1433.jpg
# Creating..../data/video_long/frame1434.jpg
# Creating..../data/video_long/frame1435.jpg
# Creating..../data/video_long/frame1436.jpg
# Creating..../data/video_long/frame1437.jpg
# Creating..../data/video_long/frame1438.jpg
# Creating..../data/video_long/frame1439.jpg
# Creating..../data/video_long/frame1440.jpg
# Creating..../data/video_long/frame1441.jpg
# Creating..../data/video_long/frame1442.jpg
# Creating..../data/video_long/frame1443.jpg
# Creating..../data/video_long/frame1444.jpg
# Creating..../data/video_long/frame1445.jpg
# Creating..../data/video_long/frame1446.jpg
# Creating..../data/video_long/frame1447.jpg
# Creating..../data/video_long/frame1448.jpg
# Creating..../data/video_long/frame1449.jpg
# Creating..../data/video_long/frame1450.jpg
# Creating..../data/video_long/frame1451.jpg
# Creating..../data/video_long/frame1452.jpg
# Creating..../data/video_long/frame1453.jpg
# Creating..../data/video_long/frame1454.jpg
# Creating..../data/video_long/frame1455.jpg
# Creating..../data/video_long/frame1456.jpg
# Creating..../data/video_long/frame1457.jpg
# Creating..../data/video_long/frame1458.jpg
# Creating..../data/video_long/frame1459.jpg
# Creating..../data/video_long/frame1460.jpg
# Creating..../data/video_long/frame1461.jpg
# Creating..../data/video_long/frame1462.jpg
# Creating..../data/video_long/frame1463.jpg
# Creating..../data/video_long/frame1464.jpg
# Creating..../data/video_long/frame1465.jpg
# Creating..../data/video_long/frame1466.jpg
# Creating..../data/video_long/frame1467.jpg
# Creating..../data/video_long/frame1468.jpg
# Creating..../data/video_long/frame1469.jpg
# Creating..../data/video_long/frame1470.jpg
# Creating..../data/video_long/frame1471.jpg
# Creating..../data/video_long/frame1472.jpg
# Creating..../data/video_long/frame1473.jpg
# Creating..../data/video_long/frame1474.jpg
# Creating..../data/video_long/frame1475.jpg
# Creating..../data/video_long/frame1476.jpg
# Creating..../data/video_long/frame1477.jpg
# Creating..../data/video_long/frame1478.jpg
# Creating..../data/video_long/frame1479.jpg
# Creating..../data/video_long/frame1480.jpg
# Creating..../data/video_long/frame1481.jpg
# Creating..../data/video_long/frame1482.jpg
# Creating..../data/video_long/frame1483.jpg
# Creating..../data/video_long/frame1484.jpg
# Creating..../data/video_long/frame1485.jpg
# Creating..../data/video_long/frame1486.jpg
# Creating..../data/video_long/frame1487.jpg
# Creating..../data/video_long/frame1488.jpg
# Creating..../data/video_long/frame1489.jpg
# Creating..../data/video_long/frame1490.jpg
# Creating..../data/video_long/frame1491.jpg
# Creating..../data/video_long/frame1492.jpg
# Creating..../data/video_long/frame1493.jpg
# Creating..../data/video_long/frame1494.jpg
# Creating..../data/video_long/frame1495.jpg
# Creating..../data/video_long/frame1496.jpg
# Creating..../data/video_long/frame1497.jpg
# Creating..../data/video_long/frame1498.jpg
# Creating..../data/video_long/frame1499.jpg
# Creating..../data/video_long/frame1500.jpg
# Creating..../data/video_long/frame1501.jpg
# Creating..../data/video_long/frame1502.jpg
# Creating..../data/video_long/frame1503.jpg
# Creating..../data/video_long/frame1504.jpg
# Creating..../data/video_long/frame1505.jpg
# Creating..../data/video_long/frame1506.jpg
# Creating..../data/video_long/frame1507.jpg
# Creating..../data/video_long/frame1508.jpg
# Creating..../data/video_long/frame1509.jpg
# Creating..../data/video_long/frame1510.jpg
# Creating..../data/video_long/frame1511.jpg
# Creating..../data/video_long/frame1512.jpg
# Creating..../data/video_long/frame1513.jpg
# Creating..../data/video_long/frame1514.jpg
# Creating..../data/video_long/frame1515.jpg
# Creating..../data/video_long/frame1516.jpg
# Creating..../data/video_long/frame1517.jpg
# Creating..../data/video_long/frame1518.jpg
# Creating..../data/video_long/frame1519.jpg
# Creating..../data/video_long/frame1520.jpg
# Creating..../data/video_long/frame1521.jpg
# Creating..../data/video_long/frame1522.jpg
# Creating..../data/video_long/frame1523.jpg
# Creating..../data/video_long/frame1524.jpg
# Creating..../data/video_long/frame1525.jpg
# Creating..../data/video_long/frame1526.jpg
# Creating..../data/video_long/frame1527.jpg
# Creating..../data/video_long/frame1528.jpg
# Creating..../data/video_long/frame1529.jpg
# Creating..../data/video_long/frame1530.jpg
# Creating..../data/video_long/frame1531.jpg
# Creating..../data/video_long/frame1532.jpg
# Creating..../data/video_long/frame1533.jpg
# Creating..../data/video_long/frame1534.jpg
# Creating..../data/video_long/frame1535.jpg
# Creating..../data/video_long/frame1536.jpg
# Creating..../data/video_long/frame1537.jpg
# Creating..../data/video_long/frame1538.jpg
# Creating..../data/video_long/frame1539.jpg
# Creating..../data/video_long/frame1540.jpg
# Creating..../data/video_long/frame1541.jpg
# Creating..../data/video_long/frame1542.jpg
# Creating..../data/video_long/frame1543.jpg
# Creating..../data/video_long/frame1544.jpg
# Creating..../data/video_long/frame1545.jpg
# Creating..../data/video_long/frame1546.jpg
# Creating..../data/video_long/frame1547.jpg
# Creating..../data/video_long/frame1548.jpg
# Creating..../data/video_long/frame1549.jpg
# Creating..../data/video_long/frame1550.jpg
# Creating..../data/video_long/frame1551.jpg
# Creating..../data/video_long/frame1552.jpg
# Creating..../data/video_long/frame1553.jpg
# Creating..../data/video_long/frame1554.jpg
# Creating..../data/video_long/frame1555.jpg
# Creating..../data/video_long/frame1556.jpg
# Creating..../data/video_long/frame1557.jpg
# Creating..../data/video_long/frame1558.jpg
# Creating..../data/video_long/frame1559.jpg
# Creating..../data/video_long/frame1560.jpg
# Creating..../data/video_long/frame1561.jpg
# Creating..../data/video_long/frame1562.jpg
# Creating..../data/video_long/frame1563.jpg
# Creating..../data/video_long/frame1564.jpg
# Creating..../data/video_long/frame1565.jpg
# Creating..../data/video_long/frame1566.jpg
# Creating..../data/video_long/frame1567.jpg
# Creating..../data/video_long/frame1568.jpg
# Creating..../data/video_long/frame1569.jpg
# Creating..../data/video_long/frame1570.jpg
# Creating..../data/video_long/frame1571.jpg
# Creating..../data/video_long/frame1572.jpg
# Creating..../data/video_long/frame1573.jpg
# ...
# Creating..../data/video_long/frame5075.jpg
# Creating..../data/video_long/frame5076.jpg
# Creating..../data/video_long/frame5077.jpg
# Creating..../data/video_long/frame5078.jpg
# Creating..../data/video_long/frame5079.jpg
# Creating..../data/video_long/frame5080.jpg
# Creating..../data/video_long/frame5081.jpg
# Creating..../data/video_long/frame5082.jpg
# Creating..../data/video_long/frame5083.jpg
# Creating..../data/video_long/frame5084.jpg
# Creating..../data/video_long/frame5085.jpg
# Creating..../data/video_long/frame5086.jpg
# Creating..../data/video_long/frame5087.jpg
# Creating..../data/video_long/frame5088.jpg
# Creating..../data/video_long/frame5089.jpg
# Creating..../data/video_long/frame5090.jpg
# Creating..../data/video_long/frame5091.jpg
# Creating..../data/video_long/frame5092.jpg
# Creating..../data/video_long/frame5093.jpg
# Creating..../data/video_long/frame5094.jpg
# Creating..../data/video_long/frame5095.jpg
# Creating..../data/video_long/frame5096.jpg
# Creating..../data/video_long/frame5097.jpg
# Creating..../data/video_long/frame5098.jpg
# Creating..../data/video_long/frame5099.jpg
# Creating..../data/video_long/frame5100.jpg
# Creating..../data/video_long/frame5101.jpg
# Creating..../data/video_long/frame5102.jpg
# Creating..../data/video_long/frame5103.jpg
# Creating..../data/video_long/frame5104.jpg
# Creating..../data/video_long/frame5105.jpg
# Creating..../data/video_long/frame5106.jpg
# Creating..../data/video_long/frame5107.jpg
# Creating..../data/video_long/frame5108.jpg
# Creating..../data/video_long/frame5109.jpg
# Creating..../data/video_long/frame5110.jpg
# Creating..../data/video_long/frame5111.jpg
# Creating..../data/video_long/frame5112.jpg
# Creating..../data/video_long/frame5113.jpg
# Creating..../data/video_long/frame5114.jpg
# Creating..../data/video_long/frame5115.jpg
# Creating..../data/video_long/frame5116.jpg
# Creating..../data/video_long/frame5117.jpg
# Creating..../data/video_long/frame5118.jpg
# Creating..../data/video_long/frame5119.jpg
# Creating..../data/video_long/frame5120.jpg
# Creating..../data/video_long/frame5121.jpg
# Creating..../data/video_long/frame5122.jpg
# Creating..../data/video_long/frame5123.jpg
# Creating..../data/video_long/frame5124.jpg
# Creating..../data/video_long/frame5125.jpg
# Creating..../data/video_long/frame5126.jpg
# Creating..../data/video_long/frame5127.jpg
# Creating..../data/video_long/frame5128.jpg
# Creating..../data/video_long/frame5129.jpg
# Creating..../data/video_long/frame5130.jpg
# Creating..../data/video_long/frame5131.jpg
# Creating..../data/video_long/frame5132.jpg
# Creating..../data/video_long/frame5133.jpg
# Creating..../data/video_long/frame5134.jpg
# Creating..../data/video_long/frame5135.jpg
# Creating..../data/video_long/frame5136.jpg
# Creating..../data/video_long/frame5137.jpg
# Creating..../data/video_long/frame5138.jpg
# Creating..../data/video_long/frame5139.jpg
# Creating..../data/video_long/frame5140.jpg
# Creating..../data/video_long/frame5141.jpg
# Creating..../data/video_long/frame5142.jpg
# Creating..../data/video_long/frame5143.jpg
# Creating..../data/video_long/frame5144.jpg
# Creating..../data/video_long/frame5145.jpg
# Creating..../data/video_long/frame5146.jpg
# Creating..../data/video_long/frame5147.jpg
# Creating..../data/video_long/frame5148.jpg
# Creating..../data/video_long/frame5149.jpg
# Creating..../data/video_long/frame5150.jpg
# Creating..../data/video_long/frame5151.jpg
# Creating..../data/video_long/frame5152.jpg
# Creating..../data/video_long/frame5153.jpg
# Creating..../data/video_long/frame5154.jpg
# Creating..../data/video_long/frame5155.jpg
# Creating..../data/video_long/frame5156.jpg
# Creating..../data/video_long/frame5157.jpg
# Creating..../data/video_long/frame5158.jpg
# Creating..../data/video_long/frame5159.jpg
# Creating..../data/video_long/frame5160.jpg
# Creating..../data/video_long/frame5161.jpg
# Creating..../data/video_long/frame5162.jpg
# Creating..../data/video_long/frame5163.jpg
# Creating..../data/video_long/frame5164.jpg
# Creating..../data/video_long/frame5165.jpg
# Creating..../data/video_long/frame5166.jpg
# Creating..../data/video_long/frame5167.jpg
# Creating..../data/video_long/frame5168.jpg
# Creating..../data/video_long/frame5169.jpg
# Creating..../data/video_long/frame5170.jpg
# Creating..../data/video_long/frame5171.jpg
# Creating..../data/video_long/frame5172.jpg
# Creating..../data/video_long/frame5173.jpg
# Creating..../data/video_long/frame5174.jpg
# Creating..../data/video_long/frame5175.jpg
# Creating..../data/video_long/frame5176.jpg
# Creating..../data/video_long/frame5177.jpg
# Creating..../data/video_long/frame5178.jpg
# Creating..../data/video_long/frame5179.jpg
# Creating..../data/video_long/frame5180.jpg
# Creating..../data/video_long/frame5181.jpg
# Creating..../data/video_long/frame5182.jpg
# Creating..../data/video_long/frame5183.jpg
# Creating..../data/video_long/frame5184.jpg
# Creating..../data/video_long/frame5185.jpg
# Creating..../data/video_long/frame5186.jpg
# Creating..../data/video_long/frame5187.jpg
# Creating..../data/video_long/frame5188.jpg
# Creating..../data/video_long/frame5189.jpg
# Creating..../data/video_long/frame5190.jpg
# Creating..../data/video_long/frame5191.jpg
# Creating..../data/video_long/frame5192.jpg
# Creating..../data/video_long/frame5193.jpg
# Creating..../data/video_long/frame5194.jpg
# Creating..../data/video_long/frame5195.jpg
# Creating..../data/video_long/frame5196.jpg
# Creating..../data/video_long/frame5197.jpg
# Creating..../data/video_long/frame5198.jpg
# Creating..../data/video_long/frame5199.jpg
# Creating..../data/video_long/frame5200.jpg
# Creating..../data/video_long/frame5201.jpg
# Creating..../data/video_long/frame5202.jpg
# Creating..../data/video_long/frame5203.jpg
# Creating..../data/video_long/frame5204.jpg
# Creating..../data/video_long/frame5205.jpg
# Creating..../data/video_long/frame5206.jpg
# Creating..../data/video_long/frame5207.jpg
# Creating..../data/video_long/frame5208.jpg
# Creating..../data/video_long/frame5209.jpg
# Creating..../data/video_long/frame5210.jpg
# Creating..../data/video_long/frame5211.jpg
# Creating..../data/video_long/frame5212.jpg
# Creating..../data/video_long/frame5213.jpg
# Creating..../data/video_long/frame5214.jpg
# Creating..../data/video_long/frame5215.jpg
# Creating..../data/video_long/frame5216.jpg
# Creating..../data/video_long/frame5217.jpg
# Creating..../data/video_long/frame5218.jpg
# Creating..../data/video_long/frame5219.jpg
# Creating..../data/video_long/frame5220.jpg
# Creating..../data/video_long/frame5221.jpg
# Creating..../data/video_long/frame5222.jpg
# Creating..../data/video_long/frame5223.jpg
# Creating..../data/video_long/frame5224.jpg
# Creating..../data/video_long/frame5225.jpg
# Creating..../data/video_long/frame5226.jpg
# Creating..../data/video_long/frame5227.jpg
# Creating..../data/video_long/frame5228.jpg
# Creating..../data/video_long/frame5229.jpg
# Creating..../data/video_long/frame5230.jpg
# Creating..../data/video_long/frame5231.jpg
# Creating..../data/video_long/frame5232.jpg
# Creating..../data/video_long/frame5233.jpg
# Creating..../data/video_long/frame5234.jpg
# Creating..../data/video_long/frame5235.jpg
# Creating..../data/video_long/frame5236.jpg
# Creating..../data/video_long/frame5237.jpg
# Creating..../data/video_long/frame5238.jpg
# Creating..../data/video_long/frame5239.jpg
# Creating..../data/video_long/frame5240.jpg
# Creating..../data/video_long/frame5241.jpg
# Creating..../data/video_long/frame5242.jpg
# Creating..../data/video_long/frame5243.jpg
# Creating..../data/video_long/frame5244.jpg
# Creating..../data/video_long/frame5245.jpg
# Creating..../data/video_long/frame5246.jpg
# Creating..../data/video_long/frame5247.jpg
# Creating..../data/video_long/frame5248.jpg
# Creating..../data/video_long/frame5249.jpg
# Creating..../data/video_long/frame5250.jpg
# Creating..../data/video_long/frame5251.jpg
# Creating..../data/video_long/frame5252.jpg
# Creating..../data/video_long/frame5253.jpg
# Creating..../data/video_long/frame5254.jpg
# Creating..../data/video_long/frame5255.jpg
# Creating..../data/video_long/frame5256.jpg
# Creating..../data/video_long/frame5257.jpg
# Creating..../data/video_long/frame5258.jpg
# Creating..../data/video_long/frame5259.jpg
# Creating..../data/video_long/frame5260.jpg
# Creating..../data/video_long/frame5261.jpg
# Creating..../data/video_long/frame5262.jpg
# Creating..../data/video_long/frame5263.jpg
# Creating..../data/video_long/frame5264.jpg
# Creating..../data/video_long/frame5265.jpg
# Creating..../data/video_long/frame5266.jpg
# Creating..../data/video_long/frame5267.jpg
# Creating..../data/video_long/frame5268.jpg
# Creating..../data/video_long/frame5269.jpg
# Creating..../data/video_long/frame5270.jpg
# Creating..../data/video_long/frame5271.jpg
# Creating..../data/video_long/frame5272.jpg
# Creating..../data/video_long/frame5273.jpg
# Creating..../data/video_long/frame5274.jpg
# Creating..../data/video_long/frame5275.jpg
# Creating..../data/video_long/frame5276.jpg
# Creating..../data/video_long/frame5277.jpg
# Creating..../data/video_long/frame5278.jpg
# Creating..../data/video_long/frame5279.jpg
# Creating..../data/video_long/frame5280.jpg
# Creating..../data/video_long/frame5281.jpg
# Creating..../data/video_long/frame5282.jpg
# Creating..../data/video_long/frame5283.jpg
# Creating..../data/video_long/frame5284.jpg
# Creating..../data/video_long/frame5285.jpg
# Creating..../data/video_long/frame5286.jpg
# Creating..../data/video_long/frame5287.jpg
# Creating..../data/video_long/frame5288.jpg
# Creating..../data/video_long/frame5289.jpg
# Creating..../data/video_long/frame5290.jpg
# Creating..../data/video_long/frame5291.jpg
# Creating..../data/video_long/frame5292.jpg
# Creating..../data/video_long/frame5293.jpg
# Creating..../data/video_long/frame5294.jpg
# Creating..../data/video_long/frame5295.jpg
# Creating..../data/video_long/frame5296.jpg
# Creating..../data/video_long/frame5297.jpg
# Creating..../data/video_long/frame5298.jpg
# Creating..../data/video_long/frame5299.jpg
# Creating..../data/video_long/frame5300.jpg
# Creating..../data/video_long/frame5301.jpg
# Creating..../data/video_long/frame5302.jpg
# Creating..../data/video_long/frame5303.jpg
# Creating..../data/video_long/frame5304.jpg
# Creating..../data/video_long/frame5305.jpg
# Creating..../data/video_long/frame5306.jpg
# Creating..../data/video_long/frame5307.jpg
# Creating..../data/video_long/frame5308.jpg
# Creating..../data/video_long/frame5309.jpg
# Creating..../data/video_long/frame5310.jpg
# Creating..../data/video_long/frame5311.jpg
# Creating..../data/video_long/frame5312.jpg
# Creating..../data/video_long/frame5313.jpg
# Creating..../data/video_long/frame5314.jpg
# Creating..../data/video_long/frame5315.jpg
# Creating..../data/video_long/frame5316.jpg
# Creating..../data/video_long/frame5317.jpg
# Creating..../data/video_long/frame5318.jpg
# Creating..../data/video_long/frame5319.jpg
# Creating..../data/video_long/frame5320.jpg
# Creating..../data/video_long/frame5321.jpg
# Creating..../data/video_long/frame5322.jpg
# Creating..../data/video_long/frame5323.jpg
# Creating..../data/video_long/frame5324.jpg
# Creating..../data/video_long/frame5325.jpg
# Creating..../data/video_long/frame5326.jpg
# Creating..../data/video_long/frame5327.jpg
# Creating..../data/video_long/frame5328.jpg
# Creating..../data/video_long/frame5329.jpg
# Creating..../data/video_long/frame5330.jpg
# Creating..../data/video_long/frame5331.jpg
# Creating..../data/video_long/frame5332.jpg
# Creating..../data/video_long/frame5333.jpg
# Creating..../data/video_long/frame5334.jpg
# Creating..../data/video_long/frame5335.jpg
# Creating..../data/video_long/frame5336.jpg
# Creating..../data/video_long/frame5337.jpg
# Creating..../data/video_long/frame5338.jpg
# Creating..../data/video_long/frame5339.jpg
# Creating..../data/video_long/frame5340.jpg
# Creating..../data/video_long/frame5341.jpg
# Creating..../data/video_long/frame5342.jpg
# Creating..../data/video_long/frame5343.jpg
# Creating..../data/video_long/frame5344.jpg
# Creating..../data/video_long/frame5345.jpg
# Creating..../data/video_long/frame5346.jpg
# Creating..../data/video_long/frame5347.jpg
# Creating..../data/video_long/frame5348.jpg
# Creating..../data/video_long/frame5349.jpg
# Creating..../data/video_long/frame5350.jpg
# Creating..../data/video_long/frame5351.jpg
# Creating..../data/video_long/frame5352.jpg
# Creating..../data/video_long/frame5353.jpg
# Creating..../data/video_long/frame5354.jpg
# Creating..../data/video_long/frame5355.jpg
# Creating..../data/video_long/frame5356.jpg
# Creating..../data/video_long/frame5357.jpg
# Creating..../data/video_long/frame5358.jpg
# Creating..../data/video_long/frame5359.jpg
# Creating..../data/video_long/frame5360.jpg
# Creating..../data/video_long/frame5361.jpg
# Creating..../data/video_long/frame5362.jpg
# Creating..../data/video_long/frame5363.jpg
# Creating..../data/video_long/frame5364.jpg
# Creating..../data/video_long/frame5365.jpg
# Creating..../data/video_long/frame5366.jpg
# Creating..../data/video_long/frame5367.jpg
# Creating..../data/video_long/frame5368.jpg
# Creating..../data/video_long/frame5369.jpg
# Creating..../data/video_long/frame5370.jpg
# Creating..../data/video_long/frame5371.jpg
# Creating..../data/video_long/frame5372.jpg
# Creating..../data/video_long/frame5373.jpg
# Creating..../data/video_long/frame5374.jpg
# Creating..../data/video_long/frame5375.jpg
# Creating..../data/video_long/frame5376.jpg
# Creating..../data/video_long/frame5377.jpg
# Creating..../data/video_long/frame5378.jpg
# Creating..../data/video_long/frame5379.jpg
# Creating..../data/video_long/frame5380.jpg
# Creating..../data/video_long/frame5381.jpg
# Creating..../data/video_long/frame5382.jpg
# Creating..../data/video_long/frame5383.jpg
# Creating..../data/video_long/frame5384.jpg
# Creating..../data/video_long/frame5385.jpg
# Creating..../data/video_long/frame5386.jpg
# Creating..../data/video_long/frame5387.jpg
# Creating..../data/video_long/frame5388.jpg
# Creating..../data/video_long/frame5389.jpg
# Creating..../data/video_long/frame5390.jpg
# Creating..../data/video_long/frame5391.jpg
# Creating..../data/video_long/frame5392.jpg
# Creating..../data/video_long/frame5393.jpg
# Creating..../data/video_long/frame5394.jpg
# Creating..../data/video_long/frame5395.jpg
# Creating..../data/video_long/frame5396.jpg
# Creating..../data/video_long/frame5397.jpg
# Creating..../data/video_long/frame5398.jpg
# Creating..../data/video_long/frame5399.jpg
# Creating..../data/video_long/frame5400.jpg
# Creating..../data/video_long/frame5401.jpg
# Creating..../data/video_long/frame5402.jpg
# Creating..../data/video_long/frame5403.jpg
# Creating..../data/video_long/frame5404.jpg
# Creating..../data/video_long/frame5405.jpg
# Creating..../data/video_long/frame5406.jpg
# Creating..../data/video_long/frame5407.jpg
# Creating..../data/video_long/frame5408.jpg
# Creating..../data/video_long/frame5409.jpg
# Creating..../data/video_long/frame5410.jpg
# Creating..../data/video_long/frame5411.jpg
# Creating..../data/video_long/frame5412.jpg
# Creating..../data/video_long/frame5413.jpg
# Creating..../data/video_long/frame5414.jpg
# Creating..../data/video_long/frame5415.jpg
# Creating..../data/video_long/frame5416.jpg
# Creating..../data/video_long/frame5417.jpg
# Creating..../data/video_long/frame5418.jpg
# Creating..../data/video_long/frame5419.jpg
# Creating..../data/video_long/frame5420.jpg
# Creating..../data/video_long/frame5421.jpg
# Creating..../data/video_long/frame5422.jpg
# Creating..../data/video_long/frame5423.jpg
# Creating..../data/video_long/frame5424.jpg
# Creating..../data/video_long/frame5425.jpg
# Creating..../data/video_long/frame5426.jpg
# Creating..../data/video_long/frame5427.jpg
# Creating..../data/video_long/frame5428.jpg
# Creating..../data/video_long/frame5429.jpg
# Creating..../data/video_long/frame5430.jpg
# Creating..../data/video_long/frame5431.jpg
# Creating..../data/video_long/frame5432.jpg
# Creating..../data/video_long/frame5433.jpg
# Creating..../data/video_long/frame5434.jpg
# Creating..../data/video_long/frame5435.jpg
# Creating..../data/video_long/frame5436.jpg
# Creating..../data/video_long/frame5437.jpg
# Creating..../data/video_long/frame5438.jpg
# Creating..../data/video_long/frame5439.jpg
# Creating..../data/video_long/frame5440.jpg
# Creating..../data/video_long/frame5441.jpg
# Creating..../data/video_long/frame5442.jpg
# Creating..../data/video_long/frame5443.jpg
# Creating..../data/video_long/frame5444.jpg
# Creating..../data/video_long/frame5445.jpg
# Creating..../data/video_long/frame5446.jpg

# %%
def print_random_images(directory_path, k, rows, cols):
    # Get a list of all files in the directory
    files = os.listdir(directory_path)
    # Filter out non-image files (assuming all images have extensions like .jpg, .png, etc.)
    image_files = [file for file in files if file.endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp'))]

    # Shuffle the list of image files
    random.shuffle(image_files)

    # Select k random images
    selected_images = image_files[:k]

    # Create a grid to display the images
    fig, axes = plt.subplots(rows, cols, figsize=(rows*5, cols*2))

    # Loop through the grid and plot images
    for i in range(rows):
        for j in range(cols):
            # If there are no more images to display, break out of the loop
            if not selected_images:
                break
            # Load and display the image
            img_path = os.path.join(directory_path, selected_images.pop())
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            axes[i, j].imshow(img)
            axes[i, j].axis('off')
            axes[i, j].set_title(os.path.basename(img_path))

    # Show the plot
    plt.show()

# %%
print_random_images('/content/data/video_long', k=6, rows=2, cols=3)

# %%
# !pip install git+https://github.com/huggingface/transformers.git
# Out:
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-2rvhn65j
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-2rvhn65j
#   Resolved https://github.com/huggingface/transformers.git to commit ce4fff0be7f6464d713f7ac3e0bbaafbc6959ae5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0.dev0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0.dev0) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0.dev0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0.dev0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0.dev0) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0.dev0) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0.dev0) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0.dev0) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.38.0.dev0) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.0.dev0) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.38.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.38.0.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.38.0.dev0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.38.0.dev0) (2024.2.2)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.38.0.dev0-py3-none-any.whl size=8505457 sha256=a2a772ce3d75d1f25b63d7da491fa6646c10f42169614d847941baa4c882bc56
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yhhu1tt2/wheels/e7/9c/5b/e1a9c8007c343041e61cc484433d512ea9274272e3fcbe7c16
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# Successfully installed transformers-4.38.0.dev0

# %%
image_processor = AutoImageProcessor.from_pretrained("LiheYoung/depth-anything-small-hf")
model = AutoModelForDepthEstimation.from_pretrained("LiheYoung/depth-anything-small-hf")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/954 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/99.2M [00:00<?, ?B/s]

# %%
def depth_estimation(directory_path, k, model, image_processor):
    # Get a list of all files in the directory
    files = os.listdir(directory_path)
    # Filter out non-image files (assuming all images have extensions like .jpg, .png, etc.)
    image_files = [file for file in files if file.endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp'))]

    # Shuffle the list of image files
    random.shuffle(image_files)

    # Select k random images
    selected_images = image_files[:k]

    # Create a grid to display the images
    fig, axes = plt.subplots(k, 2, figsize=(10, 2*k))

    for i, img_file in enumerate(selected_images):
        # Load the original image
        img_path = os.path.join(directory_path, img_file)
        original_image = Image.open(img_path)

        # Prepare image for the model
        inputs = image_processor(images=original_image, return_tensors="pt")

        with torch.no_grad():
            # Forward pass through the model
            outputs = model(**inputs)
            predicted_depth = outputs.predicted_depth

        # Interpolate to original size
        prediction = torch.nn.functional.interpolate(
            predicted_depth.unsqueeze(1),
            size=original_image.size[::-1],
            mode="bicubic",
            align_corners=False,
        )

        # Convert depth prediction to numpy array
        depth_output = prediction.squeeze().cpu().numpy()

        # Plot original image
        axes[i, 0].imshow(original_image)
        axes[i, 0].axis('off')
        axes[i, 0].set_title(f'Image{i}',)

        # Plot depth output
        axes[i, 1].imshow(depth_output,cmap = 'plasma')
        axes[i, 1].axis('off')
        axes[i, 1].set_title(f'Depth{i}')

    plt.show()



depth_estimation('/content/data/video_long', k=5, model=model, image_processor=image_processor)

# %% [markdown]
# # Sea Thru Data

# %%
# !unzip /content/drive/MyDrive/SeaThruData/D5.zip
# Out:
# Archive:  /content/drive/MyDrive/SeaThruData/D5.zip
#   inflating: D5/depth/depthLFT_3374.tif
#   inflating: D5/depth/depthLFT_3375.tif
#   inflating: D5/depth/depthLFT_3376.tif
#   inflating: D5/depth/depthLFT_3377.tif
#   inflating: D5/depth/depthLFT_3378.tif
#   inflating: D5/depth/depthLFT_3379.tif
#   inflating: D5/depth/depthLFT_3380.tif
#   inflating: D5/depth/depthLFT_3381.tif
#   inflating: D5/depth/depthLFT_3382.tif
#   inflating: D5/depth/depthLFT_3383.tif
#   inflating: D5/depth/depthLFT_3384.tif
#   inflating: D5/depth/depthLFT_3385.tif
#   inflating: D5/depth/depthLFT_3386.tif
#   inflating: D5/depth/depthLFT_3387.tif
#   inflating: D5/depth/depthLFT_3388.tif
#   inflating: D5/depth/depthLFT_3389.tif
#   inflating: D5/depth/depthLFT_3390.tif
#   inflating: D5/depth/depthLFT_3391.tif
#   inflating: D5/depth/depthLFT_3392.tif
#   inflating: D5/depth/depthLFT_3393.tif
#   inflating: D5/depth/depthLFT_3394.tif
#   inflating: D5/depth/depthLFT_3395.tif
#   inflating: D5/depth/depthLFT_3396.tif
#   inflating: D5/depth/depthLFT_3397.tif
#   inflating: D5/depth/depthLFT_3398.tif
#   inflating: D5/depth/depthLFT_3399.tif
#   inflating: D5/depth/depthLFT_3400.tif
#   inflating: D5/depth/depthLFT_3401.tif
#   inflating: D5/depth/depthLFT_3402.tif
#   inflating: D5/depth/depthLFT_3403.tif
#   inflating: D5/depth/depthLFT_3404.tif
#   inflating: D5/depth/depthLFT_3405.tif
#   inflating: D5/depth/depthLFT_3406.tif
#   inflating: D5/depth/depthLFT_3407.tif
#   inflating: D5/depth/depthLFT_3408.tif
#   inflating: D5/depth/depthLFT_3409.tif
#   inflating: D5/depth/depthLFT_3410.tif
#   inflating: D5/depth/depthLFT_3411.tif
#   inflating: D5/depth/depthLFT_3412.tif
#   inflating: D5/depth/depthLFT_3413.tif
#   inflating: D5/depth/depthLFT_3414.tif
#   inflating: D5/depth/depthLFT_3415.tif
#   inflating: D5/depth/depthLFT_3416.tif
#   inflating: D5/linearPNG/LFT_3374.png
#   inflating: D5/linearPNG/LFT_3375.png
#   inflating: D5/linearPNG/LFT_3376.png
#   inflating: D5/linearPNG/LFT_3377.png
#   inflating: D5/linearPNG/LFT_3378.png
#   inflating: D5/linearPNG/LFT_3379.png
#   inflating: D5/linearPNG/LFT_3380.png
#   inflating: D5/linearPNG/LFT_3381.png
#   inflating: D5/linearPNG/LFT_3382.png
#   inflating: D5/linearPNG/LFT_3383.png
#   inflating: D5/linearPNG/LFT_3384.png
#   inflating: D5/linearPNG/LFT_3385.png
#   inflating: D5/linearPNG/LFT_3386.png
#   inflating: D5/linearPNG/LFT_3387.png
#   inflating: D5/linearPNG/LFT_3388.png
#   inflating: D5/linearPNG/LFT_3389.png
#   inflating: D5/linearPNG/LFT_3390.png
#   inflating: D5/linearPNG/LFT_3391.png
#   inflating: D5/linearPNG/LFT_3392.png
#   inflating: D5/linearPNG/LFT_3393.png
#   inflating: D5/linearPNG/LFT_3394.png
#   inflating: D5/linearPNG/LFT_3395.png
#   inflating: D5/linearPNG/LFT_3396.png
#   inflating: D5/linearPNG/LFT_3397.png
#   inflating: D5/linearPNG/LFT_3398.png
#   inflating: D5/linearPNG/LFT_3399.png
#   inflating: D5/linearPNG/LFT_3400.png
#   inflating: D5/linearPNG/LFT_3401.png
#   inflating: D5/linearPNG/LFT_3402.png
#   inflating: D5/linearPNG/LFT_3403.png
#   inflating: D5/linearPNG/LFT_3404.png
#   inflating: D5/linearPNG/LFT_3405.png
#   inflating: D5/linearPNG/LFT_3406.png
#   inflating: D5/linearPNG/LFT_3407.png
#   inflating: D5/linearPNG/LFT_3408.png
#   inflating: D5/linearPNG/LFT_3409.png
#   inflating: D5/linearPNG/LFT_3410.png
#   inflating: D5/linearPNG/LFT_3411.png
#   inflating: D5/linearPNG/LFT_3412.png
#   inflating: D5/linearPNG/LFT_3413.png
#   inflating: D5/linearPNG/LFT_3414.png
#   inflating: D5/linearPNG/LFT_3415.png
#   inflating: D5/linearPNG/LFT_3416.png

# %%
print_random_images('/content/D5/linearPNG', k=6, rows=2, cols=3)

# %%
depth_estimation('/content/D5/linearPNG', k=5, model=model, image_processor=image_processor)

# %%
def min_max_normalize(image):
    # Get the minimum and maximum pixel values
    min_val = np.min(image)
    max_val = np.max(image)

    # Normalize the image
    normalized_image = (image - min_val) / (max_val - min_val)
    return normalized_image


def depth_estimation_seaThru(directory_path, k, model, image_processor):
    # Get a list of all files in the directory
    dir_path = os.path.join(directory_path,'linearPNG')
    files = os.listdir(dir_path)
    # Filter out non-image files (assuming all images have extensions like .jpg, .png, etc.)
    image_files = [file for file in files if file.endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp'))]

    # Shuffle the list of image files
    random.shuffle(image_files)

    # Select k random images
    selected_images = image_files[:k]

    # Create a grid to display the images
    fig, axes = plt.subplots(k, 3, figsize=(10, 2*k))

    for i, img_file in enumerate(selected_images):
        # Load the original image
        img_path = os.path.join(directory_path,'linearPNG', img_file)
        assert os.path.exists(img_path)

        original_image = Image.open(img_path)
        original_image_display = cv2.imread(img_path)

        img_lab = cv2.cvtColor(original_image_display,cv2.COLOR_BGR2Lab)
        l,a,b = cv2.split(img_lab)

        clahe = cv2.createCLAHE(clipLimit=50, tileGridSize=(8, 8))
        lumen_clahe = clahe.apply(l)
        equ = cv2.equalizeHist(l)

        updated_lab_img = cv2.merge((lumen_clahe,a,b))

        original_image_display = cv2.cvtColor(updated_lab_img,cv2.COLOR_LAB2LBGR)

        # Prepare image for the model
        inputs = image_processor(images=original_image, return_tensors="pt")

        with torch.no_grad():
            # Forward pass through the model
            outputs = model(**inputs)
            predicted_depth = outputs.predicted_depth

        # Interpolate to original size
        prediction = torch.nn.functional.interpolate(
            predicted_depth.unsqueeze(1),
            size=original_image.size[::-1],
            mode="bicubic",
            align_corners=False,
        )

        # Convert depth prediction to numpy array
        depth_output = prediction.squeeze().cpu().numpy()

        # Plot original image
        axes[i, 0].imshow(original_image_display)
        axes[i, 0].axis('off')
        axes[i, 0].set_title(f'Image{i}',)

        # Plot depth output
        axes[i, 1].imshow(depth_output,cmap = 'plasma')
        axes[i, 1].axis('off')
        axes[i, 1].set_title(f'Depth{i}')

        # Load ground truth depth from TIFF file
        gt_tiff_file = img_file.replace('.png', '.tif')
        gt_tiff_file = 'depth'+ gt_tiff_file
        gt_tiff_path = os.path.join(directory_path, 'depth', gt_tiff_file)
        gt_depth_image = Image.open(gt_tiff_path)
        gt_depth_array = np.array(gt_depth_image)
        gt_depth_normalized = min_max_normalize(gt_depth_array)


        # Plot ground truth depth
        axes[i, 2].imshow(gt_depth_normalized, cmap='plasma')
        axes[i, 2].axis('off')
        axes[i, 2].set_title(f'Ground Truth Depth {i}')


    plt.show()

depth_estimation_seaThru('/content/D5',k=5, model=model, image_processor=image_processor)

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import torch

def min_max_normalize(image):
    # Get the minimum and maximum pixel values
    min_val = np.min(image)
    max_val = np.max(image)

    # Normalize the image
    normalized_image = (image - min_val) / (max_val - min_val)
    return normalized_image

def visualize_tiff(tiff_path):
    # Open the TIFF image using PIL
    img = Image.open(tiff_path)

    # Convert to numpy array
    img_array = np.array(img)

    # Normalize the image using min-max normalization
    img_normalized = min_max_normalize(img_array)

    return img_normalized

# Load the original image and predict depth
original_image = Image.open('/content/D5/linearPNG/LFT_3374.png')
inputs = image_processor(images=original_image, return_tensors="pt")

with torch.no_grad():
    outputs = model(**inputs)
    predicted_depth = outputs.predicted_depth

# Interpolate to original size and convert to numpy array
prediction = torch.nn.functional.interpolate(
    predicted_depth.unsqueeze(1),
    size=original_image.size[::-1],
    mode="bicubic",
    align_corners=False,
)
depth_output = prediction.squeeze().cpu().numpy()

# Visualize the TIFF image and predicted depth side by side
fig, axes = plt.subplots(1, 2, figsize=(18, 6))


# Plot depth output and label it
axes[0].imshow(depth_output)
axes[0].set_title('Predicted Depth')
axes[0].axis('off')

# Visualize the TIFF image and label it
tiff_path = '/content/D5/depth/depthLFT_3374.tif'
tiff_img_normalized = visualize_tiff(tiff_path)
axes[1].imshow(tiff_img_normalized, cmap='gray')
axes[1].set_title('Depth Map from TIFF')
axes[1].axis('off')

plt.show()

# %%
def reduce_outliers_normalize(image):
    # Get the 5th and 95th percentiles
    bottom_percentile = np.percentile(image, 5)
    top_percentile = np.percentile(image, 95)

    # Clip the pixel values to the 5th and 95th percentiles
    clipped_image = np.clip(image, bottom_percentile, top_percentile)

    # Get the minimum and maximum pixel values after clipping
    min_val = np.min(clipped_image)
    max_val = np.max(clipped_image)

    # Normalize the clipped image
    normalized_image = (clipped_image - min_val) / (max_val - min_val)
    return normalized_image

# %%
img_tiff = Image.open('/content/D5/depth/depthLFT_3374.tif')
img_array_tiff = np.array(img_tiff)
img_normalized_tiff = min_max_normalize(img_array_tiff)

non_zero_mask = img_array_tiff != 0



# plt.hist(depth_output.ravel(),bins = 200,histtype='step', label= 'Output')
# plt.hist(img_array_tiff[non_zero_mask].ravel(),bins = 200, histtype='step',label = 'Ground Truth')

histr1 = cv2.calcHist([min_max_normalize(depth_output)],[0],None,[256],[0,1])
histr2 = cv2.calcHist([img_normalized_tiff[non_zero_mask]],[0],None,[256],[0,1])

eq_hist1 = cv2.equalizeHist(histr1.astype(np.uint8))
eq_hist2 = cv2.equalizeHist(histr2.astype(np.uint8))

plt.figure(figsize=(18, 6))
plt.subplot(1, 2, 1)
plt.plot(histr1,label= 'Output')
plt.plot(histr2,label = 'Ground Truth')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(eq_hist1,label= 'Output Equalized')
plt.plot(eq_hist2,label = 'Ground Truth Equalized')
plt.legend()
_ = plt.show()

# %%
def scale_offset_invariance(depth_map1, depth_map2):
    # Calculate the mean value of both depth maps
    mean1 = np.mean(depth_map1)
    mean2 = np.mean(depth_map2)

    print(mean1)
    print(mean2)

    # Calculate the scale factor
    scale_factor = mean1 / mean2

    # Adjust the second depth map by the scale factor
    depth_map2_scaled = depth_map2 * scale_factor

    # Calculate the offset
    offset = mean1 - mean2

    print(offset)

    # Adjust the second depth map by the offset
    depth_map2_adjusted = depth_map2_scaled + offset

    return depth_map2_adjusted

scale_offset_invariance_depth_output = scale_offset_invariance(img_array_tiff[non_zero_mask], depth_output)

histr1_inv = cv2.calcHist([scale_offset_invariance_depth_output],[0],None,[256],[0,1])
histr2 = cv2.calcHist([img_normalized_tiff[non_zero_mask]],[0],None,[256],[0,1])


plt.plot(histr1,label= 'Output')
plt.plot(histr2,label = 'Ground Truth')
plt.legend()
# Out:
# 5.120901
# 7.3022165
# -2.1813154

# %%
img_tiff = Image.open('/content/D5/depth/depthLFT_3374.tif')
img_array_tiff = np.array(img_tiff)
img_normalized_tiff = min_max_normalize(img_array_tiff)

# Apply histogram equalization to both images
equalized_depth_output = cv2.equalizeHist(depth_output.astype(np.uint8))
equalized_ground_truth = cv2.equalizeHist(img_array_tiff.astype(np.uint8))

non_zero_mask = img_array_tiff != 0

# Calculate histograms
histr1 = cv2.calcHist([equalized_depth_output],[0],None,[256],[0,20])
histr2 = cv2.calcHist([equalized_ground_truth[non_zero_mask]],[0],None,[256],[0,20])

# Plotting
plt.figure(figsize=(12, 6))

# Original and equalized output image
plt.subplot(2, 2, 1)
plt.imshow(depth_output, cmap='gray')
plt.title('Original Output')
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(equalized_depth_output, cmap='gray')
plt.title('Equalized Output')
plt.axis('off')

# Original and equalized ground truth image
plt.subplot(2, 2, 3)
plt.imshow(img_array_tiff, cmap='gray')
plt.title('Original Ground Truth')
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(equalized_ground_truth, cmap='gray')
plt.title('Equalized Ground Truth')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import peak_signal_noise_ratio as psnr

def scale_offset_invariance_psnr(depth_map1, depth_map2):
    # Calculate the mean value of both depth maps
    mean1 = np.mean(depth_map1)
    mean2 = np.mean(depth_map2)

    # Calculate the scale factor
    scale_factor = mean1 / mean2

    # Adjust the second depth map by the scale factor
    depth_map2_scaled = depth_map2 * scale_factor

    # Calculate the offset
    offset = mean1 - (scale_factor * mean2)

    # Adjust the second depth map by the offset
    depth_map2_adjusted = depth_map2_scaled + offset


    #Calculate the PSNR
    psnr_val = psnr(depth_map1, depth_map2_adjusted)

    return psnr_val


def scale_offset_invariance_ssim(depth_map1, depth_map2):
    # Calculate the mean value of both depth maps
    mean1 = np.mean(depth_map1)
    mean2 = np.mean(depth_map2)

    # Calculate the scale factor
    scale_factor = mean1 / mean2

    # Adjust the second depth map by the scale factor
    depth_map2_scaled = depth_map2 * scale_factor

    # Calculate the offset
    offset = mean1 - (scale_factor * mean2)

    # Adjust the second depth map by the offset
    depth_map2_adjusted = depth_map2_scaled + offset

    # Calculate the SSIM
    ssim_value, _ = ssim(depth_map1, depth_map2_adjusted, full=True)

    return ssim_value

# %%
import os
import random
import pandas as pd
import torch
import numpy as np
import scipy.stats
from PIL import Image

def min_max_normalize(image):
    # Get the minimum and maximum pixel values
    min_val = np.min(image)
    max_val = np.max(image)

    # Normalize the image
    normalized_image = (image - min_val) / (max_val - min_val)
    return normalized_image

def calculate_metrics(directory_path, k, model, image_processor):
    results = []

    # Get a list of all files in the directory
    dir_path = os.path.join(directory_path, 'linearPNG')
    files = os.listdir(dir_path)
    # Filter out non-image files (assuming all images have extensions like .jpg, .png, etc.)
    image_files = [file for file in files if file.endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp'))]

    # Load ground truth depth from TIFF file
    gt_depth_array = {}
    for img_file in image_files:
        gt_tiff_file = img_file.replace('.png', '.tif')
        gt_tiff_file = 'depth'+ gt_tiff_file
        gt_tiff_path = os.path.join(directory_path, 'depth', gt_tiff_file)
        gt_depth_image = Image.open(gt_tiff_path)
        gt_depth_array[img_file] = np.array(gt_depth_image)

    # Shuffle the list of image files
    random.shuffle(image_files)

    for i, img_file in enumerate(image_files[:k]):
        # Load the original image
        img_path = os.path.join(directory_path, 'linearPNG', img_file)
        assert os.path.exists(img_path)
        original_image = Image.open(img_path)

        # Prepare image for the model
        inputs = image_processor(images=original_image, return_tensors="pt")

        with torch.no_grad():
            # Forward pass through the model
            outputs = model(**inputs)
            predicted_depth = outputs.predicted_depth

        # Interpolate to original size
        prediction = torch.nn.functional.interpolate(
            predicted_depth.unsqueeze(1),
            size=original_image.size[::-1],
            mode="bicubic",
            align_corners=False,
        )

        # Convert depth prediction to numpy array and resize to match ground truth depth map size
        depth_output = prediction.squeeze().cpu().numpy()
        gt_depth_normalized = min_max_normalize(gt_depth_array[img_file])
        depth_output_resized = np.array(Image.fromarray(depth_output).resize(gt_depth_normalized.shape[::-1]))

        # Handle invalid or unexpected depth values
        depth_output_resized[depth_output_resized <= 0] = 1e-7  # Replace negative or zero values with a small epsilon

        # Calculate metrics
        non_zero_mask = gt_depth_normalized != 0
        absrel = np.mean(np.abs(depth_output_resized[non_zero_mask] - gt_depth_normalized[non_zero_mask]) / gt_depth_normalized[non_zero_mask])

        d = np.log(gt_depth_normalized + 1e-7) - np.log(depth_output_resized + 1e-7)
        silog = np.mean(np.square(d)) - np.square(np.sum(d))/ np.square(d.size)
        pearson_corr = scipy.stats.pearsonr(depth_output_resized.flatten(), gt_depth_normalized.flatten())[0]
        #psnr_val = psnr(gt_depth_normalized, depth_output_resized, data_range=depth_output_resized.max() - depth_output_resized.min())
        #ssim_val = ssim(gt_depth_normalized, depth_output_resized, data_range=depth_output_resized.max() - depth_output_resized.min())

        psnr_val = scale_offset_invariance_psnr(gt_depth_normalized,depth_output_resized)
        ssim_val = scale_offset_invariance_ssim(gt_depth_normalized,depth_output_resized)

        results.append({
            'Image': i,
            'Absolute Relative error (AbsRel)': absrel,
            'Scale Invarience MSE (Logscale)': silog,
            'Pearson Correlation': pearson_corr,
            'PSNR (Scale and offset Invarience)': psnr_val,
            'SSIM (Scale and offset Invarience)': ssim_val
        })

    return pd.DataFrame(results)


# Example usage:
# Replace '/content/D5' with the directory path containing your images and depth maps
metrics_df = calculate_metrics('/content/D5', k=5, model=model, image_processor=image_processor)
print(metrics_df)
# Out:
#    Image  Absolute Relative error (AbsRel)  Scale Invarience MSE (Logscale)  \
# 0      0                         23.301823                         0.348454
# 1      1                         23.968325                         0.338974
# 2      2                         30.459557                         5.440690
# 3      3                         31.136778                         0.897004
# 4      4                         37.917816                         1.123117
#
#    Pearson Correlation  PSNR (Scale and offset Invarience)  \
# 0             0.641515                           15.558391
# 1             0.449344                           14.554503
# 2            -0.248558                           11.226302
# 3            -0.050521                           12.061640
# 4            -0.140172                           11.772531
#
#    SSIM (Scale and offset Invarience)
# 0                            0.866909
# 1                            0.872923
# 2                            0.751693
# 3                            0.721298
# 4                            0.692584

# %%
metrics_df
# Out:
#    Image  Absolute Relative error (AbsRel)  Scale Invarience MSE (Logscale)  \
# 0      0                         23.301823                         0.348454
# 1      1                         23.968325                         0.338974
# 2      2                         30.459557                         5.440690
# 3      3                         31.136778                         0.897004
# 4      4                         37.917816                         1.123117
#
#    Pearson Correlation  PSNR (Scale and offset Invarience)  \
# 0             0.641515                           15.558391
# 1             0.449344                           14.554503
# 2            -0.248558                           11.226302
# 3            -0.050521                           12.061640
# 4            -0.140172                           11.772531
#
#    SSIM (Scale and offset Invarience)
# 0                            0.866909
# 1                            0.872923
# 2                            0.751693
# 3                            0.721298
# 4                            0.692584
